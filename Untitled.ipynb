# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("India_Injury_Road_Accident_Fatality_2017-2020.csv")
df.head()
# Out:
#                State  Road Accidents  during 2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
# 3              Bihar                         9600
# 4       Chhattisgarh                        13864
#
#     Road Accidents  during 2019  Road Accidents  during 2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
# 3                         10007                       8639.0
# 4                         13899                      11656.0
#
#    Accidents  Per Lakh Population - 2017  \
# 0                                   28.7
# 1                                   18.0
# 2                                   21.6
# 3                                    8.3
# 4                                   51.2
#
# ...

# %%
df.info()
df.describe()
print(df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 45 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   State                                                  37 non-null     object
#  1   Road Accidents  during 2018                            37 non-null     int64
#  2    Road Accidents  during 2019                           37 non-null     int64
#  3   Road Accidents  during 2020                            36 non-null     float64
#  4   Accidents  Per Lakh Population - 2017                  36 non-null     float64
#  5   Total Number of Accidents  Per Lakh Population - 2018  36 non-null     float64
#  6   Total Number of Accidents  Per Lakh Population - 2019  36 non-null     float64
#  7   Total Number of Accidents  Per Lakh Population - 2020  36 non-null     float64
# ...

# %%
# Step 1: Clean the column names
df.columns = df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)
#print(df.columns.tolist())
df_sorted = df.sort_values(by='Road Accidents during 2018', ascending=False)

plt.figure(figsize=(12, 8))
sns.barplot(x='Road Accidents during 2018', y='State',hue='State', data=df_sorted, palette='coolwarm')
plt.title('Road Accidents by State in 2018')
plt.xlabel('Number of Accidents')
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Road Accidents during 2019', y='State',hue='State', data=df_sorted, palette='coolwarm')
plt.title('Road Accidents by State in 2019')
plt.xlabel('Number of Accidents')
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Road Accidents during 2020', y='State',hue='State', data=df_sorted, palette='coolwarm')
plt.title('Road Accidents by State in 2020')
plt.xlabel('Number of Accidents')
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %%
df.columns = df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)
df_stacked = df[['State','Accidents per 10,000 Vehicles - 2017', 
                 'Accidents per 10,000 Vehicles - 2018', 
                 'Accidents per 10,000 Vehicles - 2019']]
df_stacked.set_index('State',inplace=True)

df_stacked.plot(kind='bar',stacked=True,figsize=(14,8),colormap='viridis')

plt.title('Accidents per 10,000 Vehicles (2017–2019) by State')
plt.xlabel('State')
plt.ylabel('Accidents per 10,000 Vehicles')
plt.legend(title='year')
plt.tight_layout()
plt.show()

# %%
df.columns = df.columns.str.strip().str.replace(r'\s+', ' ', regex=True)
df_stacked = df[['State','Accidents per 10,000 Km of Roads - 2017', 
                 'Accidents per 10,000 Km of Roads - 2018']]
df_stacked.set_index('State',inplace=True)

df_stacked.plot(kind='bar',stacked=True,figsize=(14,8),colormap='viridis')

plt.title('Accidents per 10,000 km (2017–2019) by State')
plt.xlabel('State')
plt.ylabel('Accidents per 10,000 km')
plt.legend(title='year')
plt.tight_layout()
plt.show()

# %%
columns = [
           'Accidents per 10,000 Vehicles - 2017',
           'Accidents per 10,000 Vehicles - 2018',
           'Accidents per 10,000 Vehicles - 2019',
            'Accidents per 10,000 Km of Roads - 2017',
          'Accidents per 10,000 Km of Roads - 2018']

km = [
            'Accidents per 10,000 Km of Roads - 2017',
          'Accidents per 10,000 Km of Roads - 2018']

print("📊 Year-wise Highest Accident Rates per 10,000 Vehicles and per 10,000 km :\n")

for col in columns:
    year = col.split('-')[-1].strip()
    max_idx = df[col].idxmax()
    state = df.loc[max_idx, 'State']
    value = df.loc[max_idx, col]
    per_km= df.loc[max_idx,km]
    
    print(f" In {year}, the highest accident rate was in  {state} with {value:.2f} accidents per 10,000 vehicles and {value:.2f} accidents per 10,000 km")
# Out:
# 📊 Year-wise Highest Accident Rates per 10,000 Vehicles and per 10,000 km :
#
#  In 2017, the highest accident rate was in  Madhya Pradesh with 40.50 accidents per 10,000 vehicles and 40.50 accidents per 10,000 km
#  In 2018, the highest accident rate was in  Madhya Pradesh with 38.90 accidents per 10,000 vehicles and 38.90 accidents per 10,000 km
#  In 2019, the highest accident rate was in  Madhya Pradesh with 38.40 accidents per 10,000 vehicles and 38.40 accidents per 10,000 km
#  In 2017, the highest accident rate was in  Puducherry with 5221.80 accidents per 10,000 vehicles and 5221.80 accidents per 10,000 km
#  In 2018, the highest accident rate was in  Puducherry with 3720.10 accidents per 10,000 vehicles and 3720.10 accidents per 10,000 km
